# %% [markdown]
# ## Lottery Smart Contract

# %% [markdown]
# ![lottery.png](attachment:lottery.png)

# %% [markdown]
# ![lottery1.PNG](attachment:lottery1.PNG)

# %% [markdown]
# ![lottery2.PNG](attachment:lottery2.PNG)

# %% [markdown]
# ![lottery3.PNG](attachment:lottery3.PNG)

# %% [markdown]
# ![lottery4.PNG](attachment:lottery4.PNG)

# %% [markdown]
# ![lottery5.PNG](attachment:lottery5.PNG)

# %% [markdown]
# ![lottery6.PNG](attachment:lottery6.PNG)

# %% [markdown]
# ![lottery7.PNG](attachment:lottery7.PNG)

# %% [markdown]
# ![lottery8.PNG](attachment:lottery8.PNG)

# %% [markdown]
# ![lottery9-2.PNG](attachment:lottery9-2.PNG)

# %% [markdown]
# ![lottery10.PNG](attachment:lottery10.PNG)

# %% [markdown]
# ![lottery11.PNG](attachment:lottery11.PNG)

# %% [markdown]
# Author: `Sandeep Chowdhury`

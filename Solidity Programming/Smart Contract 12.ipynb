# %% [markdown]
# ## More in Functions

# %% [markdown]
# ![morefun.PNG](attachment:morefun.PNG)

# %% [markdown]
# ### View, Pure and Simple

# %% [markdown]
# ![morefunc2_tut.png](attachment:morefunc2_tut.png)

# %% [markdown]
# Code

# %% [markdown]
# ![morefunc2.PNG](attachment:morefunc2.PNG)

# %% [markdown]
# Author: `Sandeep Chowdhury`

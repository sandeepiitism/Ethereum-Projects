# %% [markdown]
# ## Events

# %% [markdown]
# ![event_tut-2.png](attachment:event_tut-2.png)

# %% [markdown]
# ![event1-2.PNG](attachment:event1-2.PNG)

# %% [markdown]
# Example of a chat App: sending message from A to B and capturing it in blockchain

# %% [markdown]
# ![event2.PNG](attachment:event2.PNG)

# %% [markdown]
# Indexing: To capture all the transaction

# %% [markdown]
# ![event3.PNG](attachment:event3.PNG)

# %% [markdown]
# Author: `Sandeep Chowdhury`

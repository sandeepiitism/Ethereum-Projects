# %% [markdown]
# ## Passing Parameters

# %% [markdown]
# ![passingpara_tut.png](attachment:passingpara_tut.png)

# %% [markdown]
# ![passingParameters.PNG](attachment:passingParameters.PNG)

# %% [markdown]
# ![passingParameters2.PNG](attachment:passingParameters2.PNG)

# %% [markdown]
# ![passingParameters3.PNG](attachment:passingParameters3.PNG)

# %% [markdown]
# ![passingParameters4.PNG](attachment:passingParameters4.PNG)

# %% [markdown]
# Author: `Sandeep Chowdhury`

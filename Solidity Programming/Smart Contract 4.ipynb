# %% [markdown]
# ### Set as Input and Get as output
# Input --> write <br>
# Output --> just view

# %% [markdown]
# ![sol4.PNG](attachment:sol4.PNG)

# %% [markdown]
# Author: <b>`Sandeep Chowdhury`</b>

# %% [markdown]
# ## Multiple Inheritance

# %% [markdown]
# ![inheritance_tut.png](attachment:inheritance_tut.png)

# %% [markdown]
# ![Inheritance.PNG](attachment:Inheritance.PNG)

# %% [markdown]
# Author: `Sandeep Chowdhury`

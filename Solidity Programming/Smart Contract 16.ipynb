# %% [markdown]
# ## Loop

# %% [markdown]
# - If-Else <br>
# - for <br>
# - while <br>
# - do-while

# %% [markdown]
# ### If-Else

# %% [markdown]
# ![ifelse1.PNG](attachment:ifelse1.PNG)

# %% [markdown]
# ![ifelse2.PNG](attachment:ifelse2.PNG)

# %% [markdown]
# #### for

# %% [markdown]
# ![for.PNG](attachment:for.PNG)

# %% [markdown]
# #### While

# %% [markdown]
# ![while.PNG](attachment:while.PNG)

# %% [markdown]
# #### do while

# %% [markdown]
# ![doWhile.PNG](attachment:doWhile.PNG)

# %% [markdown]
# Author: `Sandeep Chowdhury`

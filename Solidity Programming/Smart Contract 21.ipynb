# %% [markdown]
# ## Visibility

# %% [markdown]
# ![visibility_tut.png](attachment:visibility_tut.png)

# %% [markdown]
# ![visibility1.PNG](attachment:visibility1.PNG)

# %% [markdown]
# ![visibility2.PNG](attachment:visibility2.PNG)

# %% [markdown]
# ![visibility3.PNG](attachment:visibility3.PNG)

# %% [markdown]
# Calling another outside contract

# %% [markdown]
# ![visibility4.PNG](attachment:visibility4.PNG)

# %% [markdown]
# ![visibility5.PNG](attachment:visibility5.PNG)

# %% [markdown]
# #### Object creation from another contract is left for demonstration......To Be Continue

# %% [markdown]
# Author: `Sandeep Chowdhury`

# %% [markdown]
# ## String

# %% [markdown]
# ![str1.PNG](attachment:str1.PNG)

# %% [markdown]
# ![str2.PNG](attachment:str2.PNG)

# %% [markdown]
# ![str3.PNG](attachment:str3.PNG)

# %% [markdown]
# Author: `Sandeep Chowdhury`

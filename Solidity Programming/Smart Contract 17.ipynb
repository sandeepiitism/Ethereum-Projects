# %% [markdown]
# ## Continue and Break

# %% [markdown]
# ### Continue

# %% [markdown]
# ![continue.PNG](attachment:continue.PNG)

# %% [markdown]
# ### Break

# %% [markdown]
# ![break.PNG](attachment:break.PNG)

# %% [markdown]
# Author: `Sandeep Chowdhury`

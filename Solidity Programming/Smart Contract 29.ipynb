# %% [markdown]
# ## Payable

# %% [markdown]
# ![payable_tut.png](attachment:payable_tut.png)

# %% [markdown]
# Contract is Payable the Ethers to the function from the deployed account

# %% [markdown]
# ![payable.PNG](attachment:payable.PNG)

# %% [markdown]
# Deployed button become payable a fixed Ethers to the contract and to the function from the address mentioned.

# %% [markdown]
# ![payable1.PNG](attachment:payable1.PNG)

# %% [markdown]
# Author: `Sandeep Chowdhury`

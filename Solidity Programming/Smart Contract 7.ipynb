# %% [markdown]
# ## Bytes

# %% [markdown]
# ![datatypes_tut-2.png](attachment:datatypes_tut-2.png)

# %% [markdown]
# Code

# %% [markdown]
# ![bytes.PNG](attachment:bytes.PNG)

# %% [markdown]
# ### Dynamic Bytes

# %% [markdown]
# ![dynamicBytes.PNG](attachment:dynamicBytes.PNG)

# %% [markdown]
# Author: `Sandeep Chowdhury`

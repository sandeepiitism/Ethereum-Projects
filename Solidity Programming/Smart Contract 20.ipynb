# %% [markdown]
# ## Mapping

# %% [markdown]
# ![ink%20%283%29.png](attachment:ink%20%283%29.png)

# %% [markdown]
# ![mapping.PNG](attachment:mapping.PNG)

# %% [markdown]
# Q1. Create a Student certificate detail account and retrieve details using his/her account.

# %% [markdown]
# ![structMapping.PNG](attachment:structMapping.PNG)

# %% [markdown]
# Q2. Create a NGO details which is capturing the donar details and the total ethereum donated till date.

# %% [markdown]
# ![donorMap1.PNG](attachment:donorMap1.PNG)

# %% [markdown]
# ![donorMap2.PNG](attachment:donorMap2.PNG)

# %% [markdown]
# Author: `Sandeep Chowdhury`

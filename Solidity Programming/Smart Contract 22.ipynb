# %% [markdown]
# ## Inheritance

# %% [markdown]
# ![inherit_tut-2.png](attachment:inherit_tut-2.png)

# %% [markdown]
# ![inherit1.PNG](attachment:inherit1.PNG)

# %% [markdown]
# Inheriting from Parent using <b>virtual</b> and <b>override</b>

# %% [markdown]
# ![inherit2.PNG](attachment:inherit2.PNG)

# %% [markdown]
# Inheriting from Child as grandchild

# %% [markdown]
# ![inherit3.PNG](attachment:inherit3.PNG)

# %% [markdown]
# Author: `Sandeep Chowdhury`

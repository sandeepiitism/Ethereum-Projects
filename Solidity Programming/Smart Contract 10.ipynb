# %% [markdown]
# ## Local Variable

# %% [markdown]
# ![localvar_tut.png](attachment:localvar_tut.png)

# %% [markdown]
# Code

# %% [markdown]
# ![localvar-2.PNG](attachment:localvar-2.PNG)

# %% [markdown]
# Author: `Sandeep Chowdhury`

# %% [markdown]
# ### Getting present account address and Assigning new account address: Ownership Transfer

# %% [markdown]
# get the <b>Owner</b> address which is the present account as shown

# %% [markdown]
# ![sol3.PNG](attachment:sol3.PNG)

# %% [markdown]
# If the account as address is changed and <b>assignOwner</b> with the new copied address, the get <b>owner</b> will display new address as shown:
#
#     `Note`: The gas price will be deducted from the new address

# %% [markdown]
# ![sol3.1.PNG](attachment:sol3.1.PNG)

# %% [markdown]
# Author: <b>`Sandeep Chowdhury`</b>

# %% [markdown]
# ### Set Default Value

# %% [markdown]
# ![defvalues.PNG](attachment:defvalues.PNG)

# %% [markdown]
# ![sol2.PNG](attachment:sol2.PNG)

# %% [markdown]
# Author: <b>`Sandeep Chowdhury`</b>

# %% [markdown]
# ## Global Variables

# %% [markdown]
# ![globalvar_tut.png](attachment:globalvar_tut.png)

# %% [markdown]
# Code

# %% [markdown]
# ![globalvar.PNG](attachment:globalvar.PNG)

# %% [markdown]
# Author: `Sandeep Chowdhury`

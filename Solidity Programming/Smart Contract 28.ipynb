# %% [markdown]
# ## Modifier

# %% [markdown]
# ![modifier-tut.png](attachment:modifier-tut.png)

# %% [markdown]
# ![modifier1.PNG](attachment:modifier1.PNG)

# %% [markdown]
# Using <b>Modifier</b> on the above code

# %% [markdown]
# ![modifier2.PNG](attachment:modifier2.PNG)

# %% [markdown]
# Codes after the for loop or if-else loop or after any return can be used in constructor as well after the _; command

# %% [markdown]
# ![modifier3.PNG](attachment:modifier3.PNG)

# %% [markdown]
# ![modifier5.PNG](attachment:modifier5.PNG)

# %% [markdown]
# Taking Manual Input

# %% [markdown]
# ![modifier6.PNG](attachment:modifier6.PNG)

# %% [markdown]
# Author: `Sandeep Chowdhury`

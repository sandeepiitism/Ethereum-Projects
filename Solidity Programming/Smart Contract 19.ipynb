# %% [markdown]
# ## Struct

# %% [markdown]
# ![struct_tut.png](attachment:struct_tut.png)

# %% [markdown]
# Assigning parameters in an <b>Array</b>

# %% [markdown]
# ![struct1.PNG](attachment:struct1.PNG)

# %% [markdown]
# Assigning Parameters using <b>Constructor</b>

# %% [markdown]
# ![struct2.PNG](attachment:struct2.PNG)

# %% [markdown]
# Updating the constructor Parameters

# %% [markdown]
# ![struct3.PNG](attachment:struct3.PNG)

# %% [markdown]
# Updating the Array Parameters

# %% [markdown]
# ![struct4.PNG](attachment:struct4.PNG)

# %% [markdown]
# Author: `Sandeep Chowdhury`

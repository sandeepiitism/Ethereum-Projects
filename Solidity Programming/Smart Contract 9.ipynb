# %% [markdown]
# ## State Variables

# %% [markdown]
# ![statevar_tut.png](attachment:statevar_tut.png)

# %% [markdown]
# Code

# %% [markdown]
# ![statevar.PNG](attachment:statevar.PNG)

# %% [markdown]
# Author: `Sandeep Chowdhury`

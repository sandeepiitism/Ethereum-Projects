# %% [markdown]
# ## Send, Transfer and Call

# %% [markdown]
# ![call_tut.png](attachment:call_tut.png)

# %% [markdown]
# ![call1.PNG](attachment:call1.PNG)

# %% [markdown]
# ![call2.PNG](attachment:call2.PNG)

# %% [markdown]
# ![call3.PNG](attachment:call3.PNG)

# %% [markdown]
# ![call4-2.PNG](attachment:call4-2.PNG)

# %% [markdown]
# Author: `Sandeep Chowdhury`

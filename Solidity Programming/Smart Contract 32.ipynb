# %% [markdown]
# ## Immutability

# %% [markdown]
# ![immutable_tut.png](attachment:immutable_tut.png)

# %% [markdown]
# ![immutable.PNG](attachment:immutable.PNG)

# %% [markdown]
# Author: `Sandeep Chowdhury`

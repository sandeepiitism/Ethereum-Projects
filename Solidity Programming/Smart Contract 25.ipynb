# %% [markdown]
# ## Override Multi-Inheritance

# %% [markdown]
# ![overrideinheritance_tut-2.png](attachment:overrideinheritance_tut-2.png)

# %% [markdown]
# ![overrideInheritance.PNG](attachment:overrideInheritance.PNG)

# %% [markdown]
# Author: `Sandeep Chowdhury`

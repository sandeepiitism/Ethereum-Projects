# %% [markdown]
# ## Error Handling: Require, Revert and Assert

# %% [markdown]
# ![error_tut.png](attachment:error_tut.png)

# %% [markdown]
# Require: Input Validation

# %% [markdown]
# ![require.PNG](attachment:require.PNG)

# %% [markdown]
# Require: Access Control

# %% [markdown]
# ![revert2.PNG](attachment:revert2.PNG)

# %% [markdown]
# Revert

# %% [markdown]
# ![revert1.PNG](attachment:revert1.PNG)

# %% [markdown]
# ![revert2.PNG](attachment:revert2.PNG)

# %% [markdown]
# Assert

# %% [markdown]
# ![assert.PNG](attachment:assert.PNG)

# %% [markdown]
# Author: `Sandeep Chowdhury`

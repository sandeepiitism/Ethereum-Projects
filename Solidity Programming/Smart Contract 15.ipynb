# %% [markdown]
# ## Constructor

# %% [markdown]
# ![constructor_tut.png](attachment:constructor_tut.png)

# %% [markdown]
# ![constructor1.PNG](attachment:constructor1.PNG)

# %% [markdown]
# ![constructor-2.PNG](attachment:constructor-2.PNG)

# %% [markdown]
# Author: `Sandeep Chowdhury`

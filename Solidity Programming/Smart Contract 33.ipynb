# %% [markdown]
# ## Data Location

# %% [markdown]
# ![calldata_tut.png](attachment:calldata_tut.png)

# %% [markdown]
# ![calldata%20%281%29.PNG](attachment:calldata%20%281%29.PNG)

# %% [markdown]
# Author: `Sandeep Chowdhury`

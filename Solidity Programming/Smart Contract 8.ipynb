# %% [markdown]
# ## Functions

# %% [markdown]
# ![funct_tut.png](attachment:funct_tut.png)

# %% [markdown]
# Code

# %% [markdown]
# ![funct.PNG](attachment:funct.PNG)

# %% [markdown]
# Author: `Sandeep Chowdhury`

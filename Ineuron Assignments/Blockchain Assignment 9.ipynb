# %% [markdown]
# ### 1. Setup Geth on your PC according to live class and perform the following operations in geth javascript console :

# %% [markdown]
# #### i. Getting current accounts list

# %% [markdown]
# ![accountlist.PNG](attachment:accountlist.PNG)

# %% [markdown]
# #### ii. Getting account balance of all accounts

# %% [markdown]
# ![sandeeptestaccount.PNG](attachment:sandeeptestaccount.PNG)

# %% [markdown]
# #### iii. Setting an account as mining account

# %% [markdown]
# ![genesis-2.PNG](attachment:genesis-2.PNG)

# %% [markdown]
# ![mining.PNG](attachment:mining.PNG)

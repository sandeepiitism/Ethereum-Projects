# %% [markdown]
# ### 1. Write a smart contract to input and output a struct type with the following details-
# i. Struct Name- Car <br>
# ii. Struct parameters- Name, Engine, Model, Manufacturing year, total, miles, mileage.

# %% [markdown]
# Code

# %% [markdown]
# ![cardetails.PNG](attachment:cardetails.PNG)

# %% [markdown]
# ### 1. What is contract code in ethereum accounts? What is it used for?

# %% [markdown]
# A "Contract code" on Ethereum is a piece of code that is written in Remix IDE and stored on the blockchain as bytecode and is immutable once created. Contract codes are majorly used for :
# - Updating state variables
# - Reading state variables
# - Logic execution

# %% [markdown]
# ### 2. What is the use of a compiler? How is code compiled and stored in ethereum blockchain?

# %% [markdown]
# In computing, a <b> compiler </b> is a computer program that translates computer code written in one programming language (the source code) into another language (the Machine code).
#
# Smart contracts are pieces of code that are stored on the blockchain and are executed by the Ethereum Virtual Machine (EVM). The contract is written in SOlidity and The Compile tab compiles the contract into bytecode—code that is understood by Ethereum.

# %% [markdown]
# ### 3. What is the storage parameter in ethereum contract accounts? What is the significance of the storage field ?

# %% [markdown]
# Storage parameters in Ethereum contract are:
# - Simple variable
# - Fixed-size array
# - Dynamic array
# - Mapping
#
# ![storage-2.PNG](attachment:storage-2.PNG)
# <br>
# <br>
# A storage trie is where all of the contract data lives. Each Ethereum account has its own storage trie. A 256-bit hash of the storage trie’s root node is stored as the storageRoot value in the global state trie

# %% [markdown]
# ### 4. What is the difference between storage variable and memory variable with respect to ethereum blockchain?

# %% [markdown]
# <b> Storage</b>: This is global memory available to all functions within the contract. This storage is a permanent storage that
# Ethereum stores on every node within its environment. <br>
# <b> Memory</b>: This is local memory available to every function within a contract. This is short lived and fleeting memory that gets torn down when the function completes its execution.

# %% [markdown]
# ### 5. Write down the gas unit requirement for the following operations in Ethereum Virtual Machine:

# %% [markdown]
# | Operations | Gas Unit Required |
# | --- | --- |
# | ADD | 3 |
# | SUBTRACT | 3 |
# | MULTIPLY | 5 |
# | JUMP | 8 |
# | ADDRESS | 2 |

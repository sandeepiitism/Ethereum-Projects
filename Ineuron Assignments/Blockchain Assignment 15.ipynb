# %% [markdown]
# ### 1. Write a solidity program to create a struct type with the following details
# a. Struct Name- Student <br>
# b. Input fields for Student struct-<br>
# - Name
# - Age
# - Roll_no
# - Marks_physics
# - Marks_maths
# - Marks_chemistry <br>
#
# c. Create a dynamic array of the Student struct type and input 5 array values from the user and return the student details when called by the array index no.

# %% [markdown]
# <b>Solution<b>:

# %% [markdown]
# At Index 0:

# %% [markdown]
# ![index0.PNG](attachment:index0.PNG)

# %% [markdown]
# At Index 1

# %% [markdown]
# ![index1.PNG](attachment:index1.PNG)

# %% [markdown]
# At Index 2

# %% [markdown]
# ![index2.PNG](attachment:index2.PNG)

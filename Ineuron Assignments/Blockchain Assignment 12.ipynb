# %% [markdown]
# ### 1. Write a solidity program to input basic salary of an employee and calculate its gross salary according to following: <br>
# a. If Basic Salary <= 10000 : HRA = 20%, DA = 80%<br>
# b. If Basic Salary <= 20000 : HRA = 25%, DA = 90%<br>
# c. If Basic Salary > 20000 : HRA = 30%, DA = 95%

# %% [markdown]
# #### Code

# %% [markdown]
# ![salary1.PNG](attachment:salary1.PNG)

# %% [markdown]
# a) If Basic Salary <= 10000

# %% [markdown]
# ![salary2.PNG](attachment:salary2.PNG)

# %% [markdown]
# b) If Basic Salary <= 20000

# %% [markdown]
# ![salary3.PNG](attachment:salary3.PNG)

# %% [markdown]
# c) If Basic Salary > 20000

# %% [markdown]
# ![salary%204.PNG](attachment:salary%204.PNG)

# %% [markdown]
# ### 1. Write , compile and show the deployment output of a smart contract with the following functionsa

# %% [markdown]
# a. A function to perform pre increment operation on an uint256 variable.<br>
# b. A function to perform post increment operation on an int256 variable.<br>
# c. A function to perform pre decrement operation on an int256 variable.<br>
# d. A function to perform post decrement operation on an uint256 variable.

# %% [markdown]
# #### Code

# %% [markdown]
# ![incdec1-2.PNG](attachment:incdec1-2.PNG)

# %% [markdown]
# a. A function to perform pre increment operation on an uint256 variable.

# %% [markdown]
# ![incdec2-2.PNG](attachment:incdec2-2.PNG)

# %% [markdown]
# b. A function to perform post increment operation on an int256 variable.

# %% [markdown]
# ![incdec3.PNG](attachment:incdec3.PNG)

# %% [markdown]
# c. A function to perform pre decrement operation on an int256 variable.

# %% [markdown]
# ![incdec4.PNG](attachment:incdec4.PNG)

# %% [markdown]
# d. A function to perform post decrement operation on an uint256 variable.

# %% [markdown]
# ![incdec5.PNG](attachment:incdec5.PNG)
